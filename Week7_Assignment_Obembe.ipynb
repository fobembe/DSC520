# %%
# Assignment: ASSIGNMENT 5
# Name:OBEMBE, Olufemi
# Date: 2021-10-17

# %%
heights_df <- read.csv("heights.csv")

# %%
head(heights_df)
# Out:
#   earn  height   sex    ed age race
# 1 50000 74.42444 male   16 45  white
# 2 60000 65.53754 female 16 58  white
# 3 30000 63.62920 female 16 29  white
# 4 50000 63.10856 female 16 91  other
# 5 51000 63.40248 female 17 39  white
# 6  9000 64.39951 female 15 26  white

# %%
install.packages("polycor")
# Out:
# Installing package into 'C:/Users/fobem/OneDrive/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'polycor' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\fobem\AppData\Local\Temp\Rtmp4G1gTZ\downloaded_packages

# %%
install.packages("ggm")
# Out:
# Installing package into 'C:/Users/fobem/OneDrive/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# Warning message:
# "dependency 'graph' is not available"also installing the dependency 'igraph'
#   There is a binary version available but the source version is later:
#        binary source needs_compilation
# igraph  1.2.6  1.2.7              TRUE
#
#   Binaries will be installed
# package 'igraph' successfully unpacked and MD5 sums checked
# package 'ggm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\fobem\AppData\Local\Temp\Rtmp4G1gTZ\downloaded_packages

# %%
install.packages("Hmisc")
# Out:
# Installing package into 'C:/Users/fobem/OneDrive/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# Hmisc  4.5-0  4.6-0              TRUE
#
#   Binaries will be installed
# package 'Hmisc' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\fobem\AppData\Local\Temp\Rtmp4G1gTZ\downloaded_packages

# %%
library("ggplot2")

# %%
# Using `cor()` compute correclation coefficients for height vs. earn

cor(heights_df$height, heights_df$earn,use="complete.obs",method="pearson")
# Out:
# [1] 0.2418481

# %%
# correlation between age vs. earn

cor(heights_df$age, heights_df$earn,use="complete.obs",method="pearson")
# Out:
# [1] 0.08100297

# %%
# correlation between ed vs. earn

cor(heights_df$ed, heights_df$earn,use="complete.obs",method="pearson")
# Out:
# [1] 0.3399765

# %%
# Spurious correlation

tech_spending <- c(18079, 18594, 19753, 20734, 20831, 23029, 23597, 23584, 25525, 27731, 29449)
suicides <- c(5427, 5688, 6198, 6462, 6635, 7336, 7248, 7491, 8161, 8578, 9000)

df <- data.frame(tech_spending,suicides)
head(df)
# Out:
#   tech_spending suicides
# 1 18079         5427
# 2 18594         5688
# 3 19753         6198
# 4 20734         6462
# 5 20831         6635
# 6 23029         7336

# %%
cor(df$tech_spending, df$suicides,use="complete.obs",method="pearson")
# Out:
# [1] 0.9920817
